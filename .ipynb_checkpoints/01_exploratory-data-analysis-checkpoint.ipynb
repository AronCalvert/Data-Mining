# %% [markdown]
# # CS4168 Project
#
# ## Data set
#
# We are using the dataset tracks2026.csv available on Brightspace. The dataset
# contains audio features and metadata for music tracks across multiple genres.
# This dataset is an excerpt of the Spotify Tracks Dataset available at:
# https://huggingface.co/datasets/maharshipandya/spotify-tracks-dataset.  The link to Hugging Face is included here only for reference.
#
# ## Project Team
#
# This project has being undertaken by
#
# | Name |	Student Number |
# -------|--------|
# Aron Calvert | 22370374 |
# Leo O'Shea | 22 |
# Eric Lonergan |22 |
# Luke Minogue |22 |

# %% [markdown]
# # 1. Exploratory Data Analysis
#
# Perform a thorough exploratory data analysis of the dataset by following the example
# EDA provided in the labs. Comment clearly on your observations and findings and how
# they can inform the following tasks on clustering and predictive analysis

# %%
# Imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("tracks2026.csv")

df.head(5)
# Out:
#                  track_id  popularity  duration_ms  explicit  danceability  \
# 0  5xmO5SbFOiVrRGrMQhL4Jk        44.0       203337     False         0.608
# 1  5cF0dROlMOK5uNZtivgu50        83.0       208786     False         0.775
# 2  4OQ9XGe11ckizN2EBnNED2        49.0       262373     False         0.797
# 3  6Grw9OtoslF9JrDJ6pgsQG         0.0       191733     False         0.582
# 4  3fGpNiwYr981n72YY4DZvB        41.0       283706     False         0.705
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.553   10    -3.493     1       0.0271        0.3930          0.000000
# 1   0.613    3    -4.586     0       0.0542        0.1090          0.000023
# 2   0.612    2    -9.043     0       0.0313        0.2710          0.000011
# 3   0.829    9    -3.517     1       0.1930        0.0522          0.000000
# 4   0.713    4    -6.676     0       0.0437        0.2600          0.000016
#
#    liveness  valence    tempo  time_signature track_genre
# ...

# %%
df.tail(5)
# Out:
#                     track_id  popularity  duration_ms  explicit  danceability  \
# 1995  4pcpqfSn8tfm6vQMMZPjpM        25.0       266133     False         0.794
# 1996  1WM80A5a4xDtlndjqjZQIv        52.0       223236     False         0.667
# 1997  4drUfuJw6c9M5cXA8p7upO         0.0       162009     False         0.541
# 1998  6ULjJomtdRstnT9BPMAf9d        58.0       120000     False         0.853
# 1999  46qnV2b4tq0QqJwIoZwMyJ        25.0       244026     False         0.746
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 1995   0.919    9    -3.037     1       0.0619        0.1540
# 1996   0.629    0    -8.493     1       0.0324        0.1750
# 1997   0.753    0    -6.512     1       0.0511        0.0677
# 1998   0.511    7    -6.451     0       0.4220        0.1880
# 1999   0.570    7   -10.599     1       0.0389        0.6660
#
#       instrumentalness  liveness  valence    tempo  time_signature track_genre
# ...

# %%
df.describe()
# Out:
#         popularity    duration_ms  danceability       energy          key  \
# count  1960.000000    2000.000000   1960.000000  1960.000000  2000.000000
# mean     39.805102  217806.433000      0.635897     0.632489     5.295500
# std      29.245904   56804.759189      0.138298     0.189087     3.567148
# min       0.000000   60000.000000      0.185000     0.090900     0.000000
# 25%       1.750000  181210.000000      0.548000     0.507750     2.000000
# 50%      45.000000  211346.000000      0.646000     0.644000     5.000000
# 75%      65.000000  246069.750000      0.738000     0.780000     8.000000
# max     100.000000  561133.000000      0.953000     0.996000    11.000000
#
#             loudness         mode  speechiness  acousticness  \
# count    1961.000000  2000.000000  2000.000000   2000.000000
# mean      400.575884     0.637500     0.078466      0.297378
# std     18065.717039     0.480842     0.076223      0.279793
# ...

# %%
print(df.dtypes)
numberic_df = df.drop(columns = ['track_genre', 'track_id', 'explicit'])
sns.heatmap(numberic_df.corr())
# Out:
# track_id             object
# popularity          float64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object
# <Axes: >

# %%
sns.pairplot(data=df[['popularity','duration_ms','tempo','danceability']].dropna())
plt.show()

# %% [markdown]
# # 2. Clustering (Descriptive Analysis)
#
# You must construct clustering pipelines using:
# *  k-means
# *  DBSCAN
#
# ## Requirements:
# * When clustering, drop the column track_genre.
# * For k-means,
# * determine a suitable value of k,
# * compute the clustering for at least two different values of k and compare
# them.
# * Visualise clusters.
# * Discuss:
#   * Whether the clusters reveal meaningful structure.
#   * Whether they align with known genre information.
# * Explain why clustering succeeded or failed.
# * Select and justify the final clustering solution

# %% [markdown]
# # 3. Classification (Predicting Popularity Category)
#
#
# Let m be the median of the column popularity. Create a new binary target variable:
#
# * popularity_binary = 0 if popularity ≤ m
#
# * popularity_binary = 1 if popularity > m
#
# Train a classification model with target popularity_binary.
#
# ## Requirements:
# * Remove the original popularity column.
# * Train a classification model that performs as well as possible.
# * Explore more than one modelling approach and justify your final choic

# %% [markdown]
# # Regression (Predicting Popularity Score)
#
#  in addition to classification, you must perform regression modelling using the original column popularity as the target variable.
#
# ## Requirements:
# * Use a separate copy of the dataset in which the original popularity column is
# retained (do not binarise).
# * Train a regression model that performs as well as possible.
# * Explore more than one modelling approach and justify your final choice.
# * Discuss whether predicting exact popularity is more difficult than predicting
# high/low popularity.
